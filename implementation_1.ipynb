# %%
import json
from datetime import timedelta, datetime

# %%
# Function to read the JSON file containing herd information
def read_herd_information(file_path):
    with open(file_path, 'r') as file:
        herd_data = json.load(file)
    return herd_data
print("Implemented & Understood this function")
# Out:
# Implemented & Understood this function

# %%
'''
# Placeholder function for updating herd information after T days (Modify as needed)
def update_herd_after_t(herd_info, elapsed_days):
    # Placeholder update for herd information after T days
    # Simulating aging or changes in the herd
    updated_herd = herd_info.copy()
    for yak in updated_herd['herd']:
        yak['age'] += elapsed_days / 365  # Assuming a year has 365 days
        yak['last_shaved_age'] = round(yak['age'] - 1, 1)  # Assuming shaving happens yearly
    return updated_herd
'''
def update_herd_after_t(herd_info, elapsed_days):
    updated_herd = herd_info.copy()
    print("Yak Details Before Elapsed Time:")
    for yak in updated_herd['herd']:
        print(f"Yak: {yak['name']}")
        print(f"Age before elapsed time: {yak['age']}")
        print(f"Last shaved age before elapsed time: {yak.get('last_shaved_age', 'Not Available')}")

    for yak in updated_herd['herd']:
        yak['age'] += elapsed_days / 365  # Assuming a year has 365 days
        yak['last_shaved_age'] = round(yak['age'] - 1, 1)  # Assuming shaving happens yearly

    print("\nYak Details After Elapsed Time:")
    for yak in updated_herd['herd']:
        print(f"Yak: {yak['name']}")
        print(f"Age after elapsed time: {yak['age']}")
        print(f"Last shaved age after elapsed time: {yak.get('last_shaved_age', 'Not Available')}")

    return updated_herd

# %%
# Function to calculate stock and herd management after T days
def simulate_stock_and_herd_after_t(herd_info, elapsed_days, stock_data):
    # Extract initial stock values
    initial_milk_stock = stock_data['milk']
    initial_skins_stock = stock_data['skins']

    # Placeholder calculation for milk and skins stock after T days
    
    milk_stock_after_t = initial_milk_stock + (elapsed_days * 10) 
    skins_stock_after_t = initial_skins_stock + (elapsed_days // 5)  # Placeholder calculation
    
    # Update the herd information after T days (e.g., simulate aging or changes)
    updated_herd_info = update_herd_after_t(herd_info, elapsed_days)

    return milk_stock_after_t, skins_stock_after_t, updated_herd_info

# %%
'''
milk_stock_after_t = initial_milk_stock + (elapsed_days * 10) 
skins_stock_after_t = initial_skins_stock + (elapsed_days // 5)

First placeholder logic assumes that, over each day (elapsed_days), 
there might be an arbitrary increase in milk production or accumulation.

In a real-world scenario, calculating stock changes might involve various factors, 
such as production rates, consumption, external supply, and other dynamic elements
that influence the stock.

For a realistic model, you would need to use actual data or formulas based on the specific factors
influencing milk production, consumption,
and any other relevant variables that impact the stock over time.
'''

# %%
# Function for order fulfillment checking stock availability
def order_fulfillment(milk_stock, skins_stock, requested_milk, requested_skins):
    # Check if requested stock is available
    if milk_stock >= requested_milk and skins_stock >= requested_skins:
        # Order can be fully fulfilled
        return {"status": 200, "message": "Order Fulfilled", "details": f"Ordered {requested_milk} units of milk and {requested_skins} skins"}
    elif milk_stock > 0 and skins_stock > 0:
        # Order partially fulfilled
        milk_fulfilled = min(milk_stock, requested_milk)
        skins_fulfilled = min(skins_stock, requested_skins)
        return {
            "status": 206,
            "message": "Partial Order Fulfilled",
            "details": f"Partially fulfilled with {milk_fulfilled} units of milk and {skins_fulfilled} skins"
        }
    else:
        # Order cannot be fulfilled
        return {"status": 404, "message": "Insufficient Stock", "details": "Stock unavailable for the order"}

# %%
# Example usage
file_path = 'sample_diverse_dataset.json'
stock_data = {"milk": 1104.480, "skins": 3}
herd_information = read_herd_information(file_path)
elapsed_time_days = 30  # Example: elapsed time in days

# Calculate stock and herd management after T days
milk_stock_after_t, skins_stock_after_t, updated_herd_info = simulate_stock_and_herd_after_t(herd_information, elapsed_time_days, stock_data)
print(f"Milk Stock after {elapsed_time_days} days: {milk_stock_after_t}")
print(f"Skins Stock after {elapsed_time_days} days: {skins_stock_after_t}")
print("Updated Herd Information after", elapsed_time_days, "days:")
print(json.dumps(updated_herd_info, indent=2))

# Example Order Fulfillment
requested_milk_units = 1500
requested_skins_units = 3
order_status = order_fulfillment(milk_stock_after_t, 
                                 skins_stock_after_t, 
                                 requested_milk_units, 
                                 requested_skins_units)
print("\nOrder Fulfillment Status:")
print(json.dumps(order_status, indent=2))
# Out:
# Yak Details Before Elapsed Time:
# Yak: Betty-1
# Age before elapsed time: 5.9
# Last shaved age before elapsed time: Not Available
# Yak: Betty-2
# Age before elapsed time: 14.7
# Last shaved age before elapsed time: Not Available
# Yak: Betty-3
# Age before elapsed time: 3.5
# Last shaved age before elapsed time: Not Available
# Yak: Betty-4
# Age before elapsed time: 14.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-5
# Age before elapsed time: 11.5
# Last shaved age before elapsed time: Not Available
# Yak: Betty-6
# Age before elapsed time: 12.4
# Last shaved age before elapsed time: Not Available
# Yak: Betty-7
# Age before elapsed time: 12.5
# Last shaved age before elapsed time: Not Available
# Yak: Betty-8
# Age before elapsed time: 10.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-9
# Age before elapsed time: 10.8
# Last shaved age before elapsed time: Not Available
# Yak: Betty-10
# Age before elapsed time: 9.9
# Last shaved age before elapsed time: Not Available
# Yak: Betty-11
# Age before elapsed time: 6.1
# Last shaved age before elapsed time: Not Available
# Yak: Betty-12
# Age before elapsed time: 3.5
# Last shaved age before elapsed time: Not Available
# Yak: Betty-13
# Age before elapsed time: 6.0
# Last shaved age before elapsed time: Not Available
# Yak: Betty-14
# Age before elapsed time: 1.8
# Last shaved age before elapsed time: Not Available
# Yak: Betty-15
# Age before elapsed time: 4.8
# Last shaved age before elapsed time: Not Available
# Yak: Betty-16
# Age before elapsed time: 9.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-17
# Age before elapsed time: 2.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-18
# Age before elapsed time: 10.5
# Last shaved age before elapsed time: Not Available
# Yak: Betty-19
# Age before elapsed time: 9.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-20
# Age before elapsed time: 10.4
# Last shaved age before elapsed time: Not Available
# Yak: Betty-21
# Age before elapsed time: 3.2
# Last shaved age before elapsed time: Not Available
# Yak: Betty-22
# Age before elapsed time: 14.9
# Last shaved age before elapsed time: Not Available
# Yak: Betty-23
# Age before elapsed time: 8.2
# Last shaved age before elapsed time: Not Available
# Yak: Betty-24
# Age before elapsed time: 6.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-25
# Age before elapsed time: 2.4
# Last shaved age before elapsed time: Not Available
# Yak: Betty-26
# Age before elapsed time: 14.1
# Last shaved age before elapsed time: Not Available
# Yak: Betty-27
# Age before elapsed time: 13.8
# Last shaved age before elapsed time: Not Available
# Yak: Betty-28
# Age before elapsed time: 11.4
# Last shaved age before elapsed time: Not Available
# Yak: Betty-29
# Age before elapsed time: 12.3
# Last shaved age before elapsed time: Not Available
# Yak: Betty-30
# Age before elapsed time: 7.2
# Last shaved age before elapsed time: Not Available
# Yak: Betty-31
# Age before elapsed time: 3.7
# Last shaved age before elapsed time: Not Available
# Yak: Betty-32
# Age before elapsed time: 9.8
# Last shaved age before elapsed time: Not Available
# Yak: Betty-33
# Age before elapsed time: 13.4
# Last shaved age before elapsed time: Not Available
# Yak: Betty-34
# Age before elapsed time: 5.8
# Last shaved age before elapsed time: Not Available
# Yak: Betty-35
# Age before elapsed time: 6.2
# Last shaved age before elapsed time: Not Available
# Yak: Betty-36
# Age before elapsed time: 5.3
# Last shaved age before elapsed time: Not Available
# Yak: Betty-37
# Age before elapsed time: 2.4
# Last shaved age before elapsed time: Not Available
# Yak: Betty-38
# Age before elapsed time: 12.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-39
# Age before elapsed time: 1.2
# Last shaved age before elapsed time: Not Available
# Yak: Betty-40
# Age before elapsed time: 5.7
# Last shaved age before elapsed time: Not Available
# Yak: Betty-41
# Age before elapsed time: 7.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-42
# Age before elapsed time: 1.4
# Last shaved age before elapsed time: Not Available
# Yak: Betty-43
# Age before elapsed time: 3.7
# Last shaved age before elapsed time: Not Available
# Yak: Betty-44
# Age before elapsed time: 2.3
# Last shaved age before elapsed time: Not Available
# Yak: Betty-45
# Age before elapsed time: 11.7
# Last shaved age before elapsed time: Not Available
# Yak: Betty-46
# Age before elapsed time: 2.0
# Last shaved age before elapsed time: Not Available
# Yak: Betty-47
# Age before elapsed time: 1.9
# Last shaved age before elapsed time: Not Available
# Yak: Betty-48
# Age before elapsed time: 3.8
# Last shaved age before elapsed time: Not Available
# Yak: Betty-49
# Age before elapsed time: 12.0
# Last shaved age before elapsed time: Not Available
# Yak: Betty-50
# Age before elapsed time: 4.5
# Last shaved age before elapsed time: Not Available
# Yak: Betty-51
# Age before elapsed time: 3.5
# Last shaved age before elapsed time: Not Available
# Yak: Betty-52
# Age before elapsed time: 8.3
# Last shaved age before elapsed time: Not Available
# Yak: Betty-53
# Age before elapsed time: 7.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-54
# Age before elapsed time: 14.5
# Last shaved age before elapsed time: Not Available
# Yak: Betty-55
# Age before elapsed time: 3.1
# Last shaved age before elapsed time: Not Available
# Yak: Betty-56
# Age before elapsed time: 14.8
# Last shaved age before elapsed time: Not Available
# Yak: Betty-57
# Age before elapsed time: 2.5
# Last shaved age before elapsed time: Not Available
# Yak: Betty-58
# Age before elapsed time: 4.8
# Last shaved age before elapsed time: Not Available
# Yak: Betty-59
# Age before elapsed time: 12.5
# Last shaved age before elapsed time: Not Available
# Yak: Betty-60
# Age before elapsed time: 3.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-61
# Age before elapsed time: 4.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-62
# Age before elapsed time: 7.2
# Last shaved age before elapsed time: Not Available
# Yak: Betty-63
# Age before elapsed time: 1.5
# Last shaved age before elapsed time: Not Available
# Yak: Betty-64
# Age before elapsed time: 8.1
# Last shaved age before elapsed time: Not Available
# Yak: Betty-65
# Age before elapsed time: 4.8
# Last shaved age before elapsed time: Not Available
# Yak: Betty-66
# Age before elapsed time: 2.3
# Last shaved age before elapsed time: Not Available
# Yak: Betty-67
# Age before elapsed time: 9.9
# Last shaved age before elapsed time: Not Available
# Yak: Betty-68
# Age before elapsed time: 9.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-69
# Age before elapsed time: 10.4
# Last shaved age before elapsed time: Not Available
# Yak: Betty-70
# Age before elapsed time: 5.2
# Last shaved age before elapsed time: Not Available
# Yak: Betty-71
# Age before elapsed time: 2.5
# Last shaved age before elapsed time: Not Available
# Yak: Betty-72
# Age before elapsed time: 1.9
# Last shaved age before elapsed time: Not Available
# Yak: Betty-73
# Age before elapsed time: 5.3
# Last shaved age before elapsed time: Not Available
# Yak: Betty-74
# Age before elapsed time: 5.1
# Last shaved age before elapsed time: Not Available
# Yak: Betty-75
# Age before elapsed time: 9.9
# Last shaved age before elapsed time: Not Available
# Yak: Betty-76
# Age before elapsed time: 9.1
# Last shaved age before elapsed time: Not Available
# Yak: Betty-77
# Age before elapsed time: 3.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-78
# Age before elapsed time: 10.7
# Last shaved age before elapsed time: Not Available
# Yak: Betty-79
# Age before elapsed time: 4.8
# Last shaved age before elapsed time: Not Available
# Yak: Betty-80
# Age before elapsed time: 1.3
# Last shaved age before elapsed time: Not Available
# Yak: Betty-81
# Age before elapsed time: 11.0
# Last shaved age before elapsed time: Not Available
# Yak: Betty-82
# Age before elapsed time: 1.2
# Last shaved age before elapsed time: Not Available
# Yak: Betty-83
# Age before elapsed time: 11.3
# Last shaved age before elapsed time: Not Available
# Yak: Betty-84
# Age before elapsed time: 9.0
# Last shaved age before elapsed time: Not Available
# Yak: Betty-85
# Age before elapsed time: 5.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-86
# Age before elapsed time: 10.5
# Last shaved age before elapsed time: Not Available
# Yak: Betty-87
# Age before elapsed time: 7.5
# Last shaved age before elapsed time: Not Available
# Yak: Betty-88
# Age before elapsed time: 1.4
# Last shaved age before elapsed time: Not Available
# Yak: Betty-89
# Age before elapsed time: 11.7
# Last shaved age before elapsed time: Not Available
# Yak: Betty-90
# Age before elapsed time: 12.5
# Last shaved age before elapsed time: Not Available
# Yak: Betty-91
# Age before elapsed time: 10.4
# Last shaved age before elapsed time: Not Available
# Yak: Betty-92
# Age before elapsed time: 10.7
# Last shaved age before elapsed time: Not Available
# Yak: Betty-93
# Age before elapsed time: 7.8
# Last shaved age before elapsed time: Not Available
# Yak: Betty-94
# Age before elapsed time: 9.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-95
# Age before elapsed time: 6.1
# Last shaved age before elapsed time: Not Available
# Yak: Betty-96
# Age before elapsed time: 10.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-97
# Age before elapsed time: 9.2
# Last shaved age before elapsed time: Not Available
# Yak: Betty-98
# Age before elapsed time: 1.6
# Last shaved age before elapsed time: Not Available
# Yak: Betty-99
# Age before elapsed time: 1.2
# Last shaved age before elapsed time: Not Available
# Yak: Betty-100
# Age before elapsed time: 14.9
# Last shaved age before elapsed time: Not Available
#
# Yak Details After Elapsed Time:
# Yak: Betty-1
# Age after elapsed time: 5.9821917808219185
# Last shaved age after elapsed time: 5.0
# Yak: Betty-2
# Age after elapsed time: 14.782191780821917
# Last shaved age after elapsed time: 13.8
# Yak: Betty-3
# Age after elapsed time: 3.5821917808219177
# Last shaved age after elapsed time: 2.6
# Yak: Betty-4
# Age after elapsed time: 14.682191780821917
# Last shaved age after elapsed time: 13.7
# Yak: Betty-5
# Age after elapsed time: 11.582191780821917
# Last shaved age after elapsed time: 10.6
# Yak: Betty-6
# Age after elapsed time: 12.482191780821918
# Last shaved age after elapsed time: 11.5
# Yak: Betty-7
# Age after elapsed time: 12.582191780821917
# Last shaved age after elapsed time: 11.6
# Yak: Betty-8
# Age after elapsed time: 10.682191780821917
# Last shaved age after elapsed time: 9.7
# Yak: Betty-9
# Age after elapsed time: 10.882191780821918
# Last shaved age after elapsed time: 9.9
# Yak: Betty-10
# Age after elapsed time: 9.982191780821918
# Last shaved age after elapsed time: 9.0
# Yak: Betty-11
# Age after elapsed time: 6.182191780821918
# Last shaved age after elapsed time: 5.2
# Yak: Betty-12
# Age after elapsed time: 3.5821917808219177
# Last shaved age after elapsed time: 2.6
# Yak: Betty-13
# Age after elapsed time: 6.082191780821918
# Last shaved age after elapsed time: 5.1
# Yak: Betty-14
# Age after elapsed time: 1.882191780821918
# Last shaved age after elapsed time: 0.9
# Yak: Betty-15
# Age after elapsed time: 4.882191780821918
# Last shaved age after elapsed time: 3.9
# Yak: Betty-16
# Age after elapsed time: 9.682191780821917
# Last shaved age after elapsed time: 8.7
# Yak: Betty-17
# Age after elapsed time: 2.682191780821918
# Last shaved age after elapsed time: 1.7
# Yak: Betty-18
# Age after elapsed time: 10.582191780821917
# Last shaved age after elapsed time: 9.6
# Yak: Betty-19
# Age after elapsed time: 9.682191780821917
# Last shaved age after elapsed time: 8.7
# Yak: Betty-20
# Age after elapsed time: 10.482191780821918
# Last shaved age after elapsed time: 9.5
# Yak: Betty-21
# Age after elapsed time: 3.282191780821918
# Last shaved age after elapsed time: 2.3
# Yak: Betty-22
# Age after elapsed time: 14.982191780821918
# Last shaved age after elapsed time: 14.0
# Yak: Betty-23
# Age after elapsed time: 8.282191780821917
# Last shaved age after elapsed time: 7.3
# Yak: Betty-24
# Age after elapsed time: 6.682191780821918
# Last shaved age after elapsed time: 5.7
# Yak: Betty-25
# Age after elapsed time: 2.4821917808219176
# Last shaved age after elapsed time: 1.5
# Yak: Betty-26
# Age after elapsed time: 14.182191780821917
# Last shaved age after elapsed time: 13.2
# Yak: Betty-27
# Age after elapsed time: 13.882191780821918
# Last shaved age after elapsed time: 12.9
# Yak: Betty-28
# Age after elapsed time: 11.482191780821918
# Last shaved age after elapsed time: 10.5
# Yak: Betty-29
# Age after elapsed time: 12.382191780821918
# Last shaved age after elapsed time: 11.4
# Yak: Betty-30
# Age after elapsed time: 7.282191780821918
# Last shaved age after elapsed time: 6.3
# Yak: Betty-31
# Age after elapsed time: 3.782191780821918
# Last shaved age after elapsed time: 2.8
# Yak: Betty-32
# Age after elapsed time: 9.882191780821918
# Last shaved age after elapsed time: 8.9
# Yak: Betty-33
# Age after elapsed time: 13.482191780821918
# Last shaved age after elapsed time: 12.5
# Yak: Betty-34
# Age after elapsed time: 5.882191780821918
# Last shaved age after elapsed time: 4.9
# Yak: Betty-35
# Age after elapsed time: 6.282191780821918
# Last shaved age after elapsed time: 5.3
# Yak: Betty-36
# Age after elapsed time: 5.382191780821918
# Last shaved age after elapsed time: 4.4
# Yak: Betty-37
# Age after elapsed time: 2.4821917808219176
# Last shaved age after elapsed time: 1.5
# Yak: Betty-38
# Age after elapsed time: 12.682191780821917
# Last shaved age after elapsed time: 11.7
# Yak: Betty-39
# Age after elapsed time: 1.2821917808219179
# Last shaved age after elapsed time: 0.3
# Yak: Betty-40
# Age after elapsed time: 5.782191780821918
# Last shaved age after elapsed time: 4.8
# Yak: Betty-41
# Age after elapsed time: 7.682191780821918
# Last shaved age after elapsed time: 6.7
# Yak: Betty-42
# Age after elapsed time: 1.4821917808219176
# Last shaved age after elapsed time: 0.5
# Yak: Betty-43
# Age after elapsed time: 3.782191780821918
# Last shaved age after elapsed time: 2.8
# Yak: Betty-44
# Age after elapsed time: 2.3821917808219175
# Last shaved age after elapsed time: 1.4
# Yak: Betty-45
# Age after elapsed time: 11.782191780821917
# Last shaved age after elapsed time: 10.8
# Yak: Betty-46
# Age after elapsed time: 2.0821917808219177
# Last shaved age after elapsed time: 1.1
# Yak: Betty-47
# Age after elapsed time: 1.9821917808219176
# Last shaved age after elapsed time: 1.0
# Yak: Betty-48
# Age after elapsed time: 3.8821917808219175
# Last shaved age after elapsed time: 2.9
# Yak: Betty-49
# Age after elapsed time: 12.082191780821917
# Last shaved age after elapsed time: 11.1
# Yak: Betty-50
# Age after elapsed time: 4.582191780821918
# Last shaved age after elapsed time: 3.6
# Yak: Betty-51
# Age after elapsed time: 3.5821917808219177
# Last shaved age after elapsed time: 2.6
# Yak: Betty-52
# Age after elapsed time: 8.382191780821918
# Last shaved age after elapsed time: 7.4
# Yak: Betty-53
# Age after elapsed time: 7.682191780821918
# Last shaved age after elapsed time: 6.7
# Yak: Betty-54
# Age after elapsed time: 14.582191780821917
# Last shaved age after elapsed time: 13.6
# Yak: Betty-55
# Age after elapsed time: 3.182191780821918
# Last shaved age after elapsed time: 2.2
# Yak: Betty-56
# Age after elapsed time: 14.882191780821918
# Last shaved age after elapsed time: 13.9
# Yak: Betty-57
# Age after elapsed time: 2.5821917808219177
# Last shaved age after elapsed time: 1.6
# Yak: Betty-58
# Age after elapsed time: 4.882191780821918
# Last shaved age after elapsed time: 3.9
# Yak: Betty-59
# Age after elapsed time: 12.582191780821917
# Last shaved age after elapsed time: 11.6
# Yak: Betty-60
# Age after elapsed time: 3.682191780821918
# Last shaved age after elapsed time: 2.7
# Yak: Betty-61
# Age after elapsed time: 4.682191780821918
# Last shaved age after elapsed time: 3.7
# Yak: Betty-62
# Age after elapsed time: 7.282191780821918
# Last shaved age after elapsed time: 6.3
# Yak: Betty-63
# Age after elapsed time: 1.5821917808219177
# Last shaved age after elapsed time: 0.6
# Yak: Betty-64
# Age after elapsed time: 8.182191780821917
# Last shaved age after elapsed time: 7.2
# Yak: Betty-65
# Age after elapsed time: 4.882191780821918
# Last shaved age after elapsed time: 3.9
# Yak: Betty-66
# Age after elapsed time: 2.3821917808219175
# Last shaved age after elapsed time: 1.4
# Yak: Betty-67
# Age after elapsed time: 9.982191780821918
# Last shaved age after elapsed time: 9.0
# Yak: Betty-68
# Age after elapsed time: 9.682191780821917
# Last shaved age after elapsed time: 8.7
# Yak: Betty-69
# Age after elapsed time: 10.482191780821918
# Last shaved age after elapsed time: 9.5
# Yak: Betty-70
# Age after elapsed time: 5.282191780821918
# Last shaved age after elapsed time: 4.3
# Yak: Betty-71
# Age after elapsed time: 2.5821917808219177
# Last shaved age after elapsed time: 1.6
# Yak: Betty-72
# Age after elapsed time: 1.9821917808219176
# Last shaved age after elapsed time: 1.0
# Yak: Betty-73
# Age after elapsed time: 5.382191780821918
# Last shaved age after elapsed time: 4.4
# Yak: Betty-74
# Age after elapsed time: 5.182191780821918
# Last shaved age after elapsed time: 4.2
# Yak: Betty-75
# Age after elapsed time: 9.982191780821918
# Last shaved age after elapsed time: 9.0
# Yak: Betty-76
# Age after elapsed time: 9.182191780821917
# Last shaved age after elapsed time: 8.2
# Yak: Betty-77
# Age after elapsed time: 3.682191780821918
# Last shaved age after elapsed time: 2.7
# Yak: Betty-78
# Age after elapsed time: 10.782191780821917
# Last shaved age after elapsed time: 9.8
# Yak: Betty-79
# Age after elapsed time: 4.882191780821918
# Last shaved age after elapsed time: 3.9
# Yak: Betty-80
# Age after elapsed time: 1.382191780821918
# Last shaved age after elapsed time: 0.4
# Yak: Betty-81
# Age after elapsed time: 11.082191780821917
# Last shaved age after elapsed time: 10.1
# Yak: Betty-82
# Age after elapsed time: 1.2821917808219179
# Last shaved age after elapsed time: 0.3
# Yak: Betty-83
# Age after elapsed time: 11.382191780821918
# Last shaved age after elapsed time: 10.4
# Yak: Betty-84
# Age after elapsed time: 9.082191780821917
# Last shaved age after elapsed time: 8.1
# Yak: Betty-85
# Age after elapsed time: 5.682191780821918
# Last shaved age after elapsed time: 4.7
# Yak: Betty-86
# Age after elapsed time: 10.582191780821917
# Last shaved age after elapsed time: 9.6
# Yak: Betty-87
# Age after elapsed time: 7.582191780821918
# Last shaved age after elapsed time: 6.6
# Yak: Betty-88
# Age after elapsed time: 1.4821917808219176
# Last shaved age after elapsed time: 0.5
# Yak: Betty-89
# Age after elapsed time: 11.782191780821917
# Last shaved age after elapsed time: 10.8
# Yak: Betty-90
# Age after elapsed time: 12.582191780821917
# Last shaved age after elapsed time: 11.6
# Yak: Betty-91
# Age after elapsed time: 10.482191780821918
# Last shaved age after elapsed time: 9.5
# Yak: Betty-92
# Age after elapsed time: 10.782191780821917
# Last shaved age after elapsed time: 9.8
# Yak: Betty-93
# Age after elapsed time: 7.882191780821918
# Last shaved age after elapsed time: 6.9
# Yak: Betty-94
# Age after elapsed time: 9.682191780821917
# Last shaved age after elapsed time: 8.7
# Yak: Betty-95
# Age after elapsed time: 6.182191780821918
# Last shaved age after elapsed time: 5.2
# Yak: Betty-96
# Age after elapsed time: 10.682191780821917
# Last shaved age after elapsed time: 9.7
# Yak: Betty-97
# Age after elapsed time: 9.282191780821917
# Last shaved age after elapsed time: 8.3
# Yak: Betty-98
# Age after elapsed time: 1.6821917808219178
# Last shaved age after elapsed time: 0.7
# Yak: Betty-99
# Age after elapsed time: 1.2821917808219179
# Last shaved age after elapsed time: 0.3
# Yak: Betty-100
# Age after elapsed time: 14.982191780821918
# Last shaved age after elapsed time: 14.0
# Milk Stock after 30 days: 1404.48
# Skins Stock after 30 days: 9
# Updated Herd Information after 30 days:
# {
#   "herd": [
#     {
#       "name": "Betty-1",
#       "age": 5.9821917808219185,
#       "health": "excellent",
#       "behavior": "calm",
#       "last_shaved_age": 5.0
#     },
#     {
#       "name": "Betty-2",
#       "age": 14.782191780821917,
#       "health": "fair",
#       "behavior": "stubborn",
#       "last_shaved_age": 13.8
#     },
#     {
#       "name": "Betty-3",
#       "age": 3.5821917808219177,
#       "health": "excellent",
#       "behavior": "calm",
#       "last_shaved_age": 2.6
#     },
#     {
#       "name": "Betty-4",
#       "age": 14.682191780821917,
#       "health": "good",
#       "behavior": "playful",
#       "last_shaved_age": 13.7
#     },
#     {
#       "name": "Betty-5",
#       "age": 11.582191780821917,
#       "health": "good",
#       "behavior": "aggressive",
#       "last_shaved_age": 10.6
#     },
#     {
#       "name": "Betty-6",
#       "age": 12.482191780821918,
#       "health": "excellent",
#       "behavior": "calm",
#       "last_shaved_age": 11.5
#     },
#     {
#       "name": "Betty-7",
#       "age": 12.582191780821917,
#       "health": "excellent",
#       "behavior": "stubborn",
#       "last_shaved_age": 11.6
#     },
#     {
#       "name": "Betty-8",
#       "age": 10.682191780821917,
#       "health": "excellent",
#       "behavior": "calm",
#       "last_shaved_age": 9.7
#     },
#     {
#       "name": "Betty-9",
#       "age": 10.882191780821918,
#       "health": "poor",
#       "behavior": "calm",
#       "last_shaved_age": 9.9
#     },
#     {
#       "name": "Betty-10",
#       "age": 9.982191780821918,
#       "health": "fair",
#       "behavior": "playful",
#       "last_shaved_age": 9.0
#     },
#     {
#       "name": "Betty-11",
#       "age": 6.182191780821918,
#       "health": "poor",
#       "behavior": "aggressive",
#       "last_shaved_age": 5.2
#     },
#     {
#       "name": "Betty-12",
#       "age": 3.5821917808219177,
#       "health": "fair",
#       "behavior": "aggressive",
#       "last_shaved_age": 2.6
#     },
#     {
#       "name": "Betty-13",
#       "age": 6.082191780821918,
#       "health": "fair",
#       "behavior": "aggressive",
#       "last_shaved_age": 5.1
#     },
#     {
#       "name": "Betty-14",
#       "age": 1.882191780821918,
#       "health": "good",
#       "behavior": "aggressive",
#       "last_shaved_age": 0.9
#     },
#     {
#       "name": "Betty-15",
#       "age": 4.882191780821918,
#       "health": "poor",
#       "behavior": "playful",
#       "last_shaved_age": 3.9
#     },
#     {
#       "name": "Betty-16",
#       "age": 9.682191780821917,
#       "health": "excellent",
#       "behavior": "stubborn",
#       "last_shaved_age": 8.7
#     },
#     {
#       "name": "Betty-17",
#       "age": 2.682191780821918,
#       "health": "fair",
#       "behavior": "aggressive",
#       "last_shaved_age": 1.7
#     },
#     {
#       "name": "Betty-18",
#       "age": 10.582191780821917,
#       "health": "fair",
#       "behavior": "playful",
#       "last_shaved_age": 9.6
#     },
#     {
#       "name": "Betty-19",
#       "age": 9.682191780821917,
#       "health": "good",
#       "behavior": "aggressive",
#       "last_shaved_age": 8.7
#     },
#     {
#       "name": "Betty-20",
#       "age": 10.482191780821918,
#       "health": "poor",
#       "behavior": "aggressive",
#       "last_shaved_age": 9.5
#     },
#     {
#       "name": "Betty-21",
#       "age": 3.282191780821918,
#       "health": "excellent",
#       "behavior": "aggressive",
#       "last_shaved_age": 2.3
#     },
#     {
#       "name": "Betty-22",
#       "age": 14.982191780821918,
#       "health": "fair",
#       "behavior": "playful",
#       "last_shaved_age": 14.0
#     },
#     {
#       "name": "Betty-23",
#       "age": 8.282191780821917,
#       "health": "fair",
#       "behavior": "calm",
#       "last_shaved_age": 7.3
#     },
#     {
#       "name": "Betty-24",
#       "age": 6.682191780821918,
#       "health": "fair",
#       "behavior": "aggressive",
#       "last_shaved_age": 5.7
#     },
#     {
#       "name": "Betty-25",
#       "age": 2.4821917808219176,
#       "health": "poor",
#       "behavior": "stubborn",
#       "last_shaved_age": 1.5
#     },
#     {
#       "name": "Betty-26",
#       "age": 14.182191780821917,
#       "health": "poor",
#       "behavior": "calm",
#       "last_shaved_age": 13.2
#     },
#     {
#       "name": "Betty-27",
#       "age": 13.882191780821918,
#       "health": "excellent",
#       "behavior": "playful",
#       "last_shaved_age": 12.9
#     },
#     {
#       "name": "Betty-28",
#       "age": 11.482191780821918,
#       "health": "fair",
#       "behavior": "aggressive",
#       "last_shaved_age": 10.5
#     },
#     {
#       "name": "Betty-29",
#       "age": 12.382191780821918,
#       "health": "poor",
#       "behavior": "aggressive",
#       "last_shaved_age": 11.4
#     },
#     {
#       "name": "Betty-30",
#       "age": 7.282191780821918,
#       "health": "excellent",
#       "behavior": "aggressive",
#       "last_shaved_age": 6.3
#     },
#     {
#       "name": "Betty-31",
#       "age": 3.782191780821918,
#       "health": "fair",
#       "behavior": "calm",
#       "last_shaved_age": 2.8
#     },
#     {
#       "name": "Betty-32",
#       "age": 9.882191780821918,
#       "health": "fair",
#       "behavior": "aggressive",
#       "last_shaved_age": 8.9
#     },
#     {
#       "name": "Betty-33",
#       "age": 13.482191780821918,
#       "health": "poor",
#       "behavior": "calm",
#       "last_shaved_age": 12.5
#     },
#     {
#       "name": "Betty-34",
#       "age": 5.882191780821918,
#       "health": "excellent",
#       "behavior": "aggressive",
#       "last_shaved_age": 4.9
#     },
#     {
#       "name": "Betty-35",
#       "age": 6.282191780821918,
#       "health": "excellent",
#       "behavior": "stubborn",
#       "last_shaved_age": 5.3
#     },
#     {
#       "name": "Betty-36",
#       "age": 5.382191780821918,
#       "health": "good",
#       "behavior": "playful",
#       "last_shaved_age": 4.4
#     },
#     {
#       "name": "Betty-37",
#       "age": 2.4821917808219176,
#       "health": "excellent",
#       "behavior": "stubborn",
#       "last_shaved_age": 1.5
#     },
#     {
#       "name": "Betty-38",
#       "age": 12.682191780821917,
#       "health": "fair",
#       "behavior": "stubborn",
#       "last_shaved_age": 11.7
#     },
#     {
#       "name": "Betty-39",
#       "age": 1.2821917808219179,
#       "health": "good",
#       "behavior": "aggressive",
#       "last_shaved_age": 0.3
#     },
#     {
#       "name": "Betty-40",
#       "age": 5.782191780821918,
#       "health": "excellent",
#       "behavior": "playful",
#       "last_shaved_age": 4.8
#     },
#     {
#       "name": "Betty-41",
#       "age": 7.682191780821918,
#       "health": "fair",
#       "behavior": "aggressive",
#       "last_shaved_age": 6.7
#     },
#     {
#       "name": "Betty-42",
#       "age": 1.4821917808219176,
#       "health": "poor",
#       "behavior": "calm",
#       "last_shaved_age": 0.5
#     },
#     {
#       "name": "Betty-43",
#       "age": 3.782191780821918,
#       "health": "excellent",
#       "behavior": "playful",
#       "last_shaved_age": 2.8
#     },
#     {
#       "name": "Betty-44",
#       "age": 2.3821917808219175,
#       "health": "excellent",
#       "behavior": "aggressive",
#       "last_shaved_age": 1.4
#     },
#     {
#       "name": "Betty-45",
#       "age": 11.782191780821917,
#       "health": "good",
#       "behavior": "stubborn",
#       "last_shaved_age": 10.8
#     },
#     {
#       "name": "Betty-46",
#       "age": 2.0821917808219177,
#       "health": "fair",
#       "behavior": "calm",
#       "last_shaved_age": 1.1
#     },
#     {
#       "name": "Betty-47",
#       "age": 1.9821917808219176,
#       "health": "poor",
#       "behavior": "stubborn",
#       "last_shaved_age": 1.0
#     },
#     {
#       "name": "Betty-48",
#       "age": 3.8821917808219175,
#       "health": "fair",
#       "behavior": "calm",
#       "last_shaved_age": 2.9
#     },
#     {
#       "name": "Betty-49",
#       "age": 12.082191780821917,
#       "health": "excellent",
#       "behavior": "calm",
#       "last_shaved_age": 11.1
#     },
#     {
#       "name": "Betty-50",
#       "age": 4.582191780821918,
#       "health": "fair",
#       "behavior": "playful",
#       "last_shaved_age": 3.6
#     },
#     {
#       "name": "Betty-51",
#       "age": 3.5821917808219177,
#       "health": "fair",
#       "behavior": "stubborn",
#       "last_shaved_age": 2.6
#     },
#     {
#       "name": "Betty-52",
#       "age": 8.382191780821918,
#       "health": "fair",
#       "behavior": "aggressive",
#       "last_shaved_age": 7.4
#     },
#     {
#       "name": "Betty-53",
#       "age": 7.682191780821918,
#       "health": "good",
#       "behavior": "aggressive",
#       "last_shaved_age": 6.7
#     },
#     {
#       "name": "Betty-54",
#       "age": 14.582191780821917,
#       "health": "excellent",
#       "behavior": "calm",
#       "last_shaved_age": 13.6
#     },
#     {
#       "name": "Betty-55",
#       "age": 3.182191780821918,
#       "health": "excellent",
#       "behavior": "calm",
#       "last_shaved_age": 2.2
#     },
#     {
#       "name": "Betty-56",
#       "age": 14.882191780821918,
#       "health": "fair",
#       "behavior": "playful",
#       "last_shaved_age": 13.9
#     },
#     {
#       "name": "Betty-57",
#       "age": 2.5821917808219177,
#       "health": "poor",
#       "behavior": "stubborn",
#       "last_shaved_age": 1.6
#     },
#     {
#       "name": "Betty-58",
#       "age": 4.882191780821918,
#       "health": "good",
#       "behavior": "stubborn",
#       "last_shaved_age": 3.9
#     },
#     {
#       "name": "Betty-59",
#       "age": 12.582191780821917,
#       "health": "poor",
#       "behavior": "aggressive",
#       "last_shaved_age": 11.6
#     },
#     {
#       "name": "Betty-60",
#       "age": 3.682191780821918,
#       "health": "excellent",
#       "behavior": "stubborn",
#       "last_shaved_age": 2.7
#     },
#     {
#       "name": "Betty-61",
#       "age": 4.682191780821918,
#       "health": "good",
#       "behavior": "stubborn",
#       "last_shaved_age": 3.7
#     },
#     {
#       "name": "Betty-62",
#       "age": 7.282191780821918,
#       "health": "fair",
#       "behavior": "aggressive",
#       "last_shaved_age": 6.3
#     },
#     {
#       "name": "Betty-63",
#       "age": 1.5821917808219177,
#       "health": "poor",
#       "behavior": "stubborn",
#       "last_shaved_age": 0.6
#     },
#     {
#       "name": "Betty-64",
#       "age": 8.182191780821917,
#       "health": "poor",
#       "behavior": "calm",
#       "last_shaved_age": 7.2
#     },
#     {
#       "name": "Betty-65",
#       "age": 4.882191780821918,
#       "health": "excellent",
#       "behavior": "stubborn",
#       "last_shaved_age": 3.9
#     },
#     {
#       "name": "Betty-66",
#       "age": 2.3821917808219175,
#       "health": "excellent",
#       "behavior": "stubborn",
#       "last_shaved_age": 1.4
#     },
#     {
#       "name": "Betty-67",
#       "age": 9.982191780821918,
#       "health": "poor",
#       "behavior": "playful",
#       "last_shaved_age": 9.0
#     },
#     {
#       "name": "Betty-68",
#       "age": 9.682191780821917,
#       "health": "good",
#       "behavior": "playful",
#       "last_shaved_age": 8.7
#     },
#     {
#       "name": "Betty-69",
#       "age": 10.482191780821918,
#       "health": "excellent",
#       "behavior": "aggressive",
#       "last_shaved_age": 9.5
#     },
#     {
#       "name": "Betty-70",
#       "age": 5.282191780821918,
#       "health": "fair",
#       "behavior": "stubborn",
#       "last_shaved_age": 4.3
#     },
#     {
#       "name": "Betty-71",
#       "age": 2.5821917808219177,
#       "health": "excellent",
#       "behavior": "stubborn",
#       "last_shaved_age": 1.6
#     },
#     {
#       "name": "Betty-72",
#       "age": 1.9821917808219176,
#       "health": "fair",
#       "behavior": "aggressive",
#       "last_shaved_age": 1.0
#     },
#     {
#       "name": "Betty-73",
#       "age": 5.382191780821918,
#       "health": "good",
#       "behavior": "calm",
#       "last_shaved_age": 4.4
#     },
#     {
#       "name": "Betty-74",
#       "age": 5.182191780821918,
#       "health": "fair",
#       "behavior": "aggressive",
#       "last_shaved_age": 4.2
#     },
#     {
#       "name": "Betty-75",
#       "age": 9.982191780821918,
#       "health": "excellent",
#       "behavior": "playful",
#       "last_shaved_age": 9.0
#     },
#     {
#       "name": "Betty-76",
#       "age": 9.182191780821917,
#       "health": "poor",
#       "behavior": "stubborn",
#       "last_shaved_age": 8.2
#     },
#     {
#       "name": "Betty-77",
#       "age": 3.682191780821918,
#       "health": "good",
#       "behavior": "aggressive",
#       "last_shaved_age": 2.7
#     },
#     {
#       "name": "Betty-78",
#       "age": 10.782191780821917,
#       "health": "good",
#       "behavior": "playful",
#       "last_shaved_age": 9.8
#     },
#     {
#       "name": "Betty-79",
#       "age": 4.882191780821918,
#       "health": "good",
#       "behavior": "aggressive",
#       "last_shaved_age": 3.9
#     },
#     {
#       "name": "Betty-80",
#       "age": 1.382191780821918,
#       "health": "good",
#       "behavior": "aggressive",
#       "last_shaved_age": 0.4
#     },
#     {
#       "name": "Betty-81",
#       "age": 11.082191780821917,
#       "health": "good",
#       "behavior": "stubborn",
#       "last_shaved_age": 10.1
#     },
#     {
#       "name": "Betty-82",
#       "age": 1.2821917808219179,
#       "health": "fair",
#       "behavior": "stubborn",
#       "last_shaved_age": 0.3
#     },
#     {
#       "name": "Betty-83",
#       "age": 11.382191780821918,
#       "health": "good",
#       "behavior": "playful",
#       "last_shaved_age": 10.4
#     },
#     {
#       "name": "Betty-84",
#       "age": 9.082191780821917,
#       "health": "good",
#       "behavior": "calm",
#       "last_shaved_age": 8.1
#     },
#     {
#       "name": "Betty-85",
#       "age": 5.682191780821918,
#       "health": "fair",
#       "behavior": "stubborn",
#       "last_shaved_age": 4.7
#     },
#     {
#       "name": "Betty-86",
#       "age": 10.582191780821917,
#       "health": "poor",
#       "behavior": "aggressive",
#       "last_shaved_age": 9.6
#     },
#     {
#       "name": "Betty-87",
#       "age": 7.582191780821918,
#       "health": "good",
#       "behavior": "calm",
#       "last_shaved_age": 6.6
#     },
#     {
#       "name": "Betty-88",
#       "age": 1.4821917808219176,
#       "health": "excellent",
#       "behavior": "playful",
#       "last_shaved_age": 0.5
#     },
#     {
#       "name": "Betty-89",
#       "age": 11.782191780821917,
#       "health": "poor",
#       "behavior": "playful",
#       "last_shaved_age": 10.8
#     },
#     {
#       "name": "Betty-90",
#       "age": 12.582191780821917,
#       "health": "fair",
#       "behavior": "stubborn",
#       "last_shaved_age": 11.6
#     },
#     {
#       "name": "Betty-91",
#       "age": 10.482191780821918,
#       "health": "good",
#       "behavior": "calm",
#       "last_shaved_age": 9.5
#     },
#     {
#       "name": "Betty-92",
#       "age": 10.782191780821917,
#       "health": "fair",
#       "behavior": "playful",
#       "last_shaved_age": 9.8
#     },
#     {
#       "name": "Betty-93",
#       "age": 7.882191780821918,
#       "health": "good",
#       "behavior": "stubborn",
#       "last_shaved_age": 6.9
#     },
#     {
#       "name": "Betty-94",
#       "age": 9.682191780821917,
#       "health": "poor",
#       "behavior": "stubborn",
#       "last_shaved_age": 8.7
#     },
#     {
#       "name": "Betty-95",
#       "age": 6.182191780821918,
#       "health": "good",
#       "behavior": "playful",
#       "last_shaved_age": 5.2
#     },
#     {
#       "name": "Betty-96",
#       "age": 10.682191780821917,
#       "health": "fair",
#       "behavior": "aggressive",
#       "last_shaved_age": 9.7
#     },
#     {
#       "name": "Betty-97",
#       "age": 9.282191780821917,
#       "health": "excellent",
#       "behavior": "stubborn",
#       "last_shaved_age": 8.3
#     },
#     {
#       "name": "Betty-98",
#       "age": 1.6821917808219178,
#       "health": "poor",
#       "behavior": "stubborn",
#       "last_shaved_age": 0.7
#     },
#     {
#       "name": "Betty-99",
#       "age": 1.2821917808219179,
#       "health": "good",
#       "behavior": "stubborn",
#       "last_shaved_age": 0.3
#     },
#     {
#       "name": "Betty-100",
#       "age": 14.982191780821918,
#       "health": "good",
#       "behavior": "calm",
#       "last_shaved_age": 14.0
#     }
#   ]
# }
#
# Order Fulfillment Status:
# {
#   "status": 206,
#   "message": "Partial Order Fulfilled",
#   "details": "Partially fulfilled with 1404.48 units of milk and 3 skins"
# }

# %% [markdown]
# 1. Develop anamolies
# 2. Check the code
# 3. Make this automated asking the user to input the stuff
